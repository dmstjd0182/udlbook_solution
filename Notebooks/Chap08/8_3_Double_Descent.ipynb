# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./sample_data/mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./sample_data/mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'], dtype=torch.float32)
  y_train = torch.tensor(data['y'], dtype=torch.long)
  x_test= torch.tensor(data['x_test'], dtype=torch.float32)
  y_test = torch.tensor(data['y_test'], dtype=torch.long)

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TO DO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden, n_hidden in enumerate(hidden_variables):
    print(f'Training model with {n_hidden:3d} hidden variables')
    # Get a model
    model = get_model(n_hidden) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden] = errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.301439, train error 89.30,  test loss 2.302764, test error 89.62
# Epoch   100, train loss 2.256309, train error 87.00,  test loss 2.274196, test error 87.12
# Epoch   200, train loss 2.242265, train error 86.60,  test loss 2.260324, test error 87.03
# Epoch   300, train loss 1.949963, train error 72.95,  test loss 1.823777, test error 71.62
# Epoch   400, train loss 1.914807, train error 70.72,  test loss 1.766979, test error 69.53
# Epoch   500, train loss 1.908553, train error 71.32,  test loss 1.746880, test error 70.20
# Epoch   600, train loss 1.904758, train error 71.05,  test loss 1.747692, test error 69.57
# Epoch   700, train loss 1.904727, train error 71.70,  test loss 1.742998, test error 70.30
# Epoch   800, train loss 1.903137, train error 71.47,  test loss 1.737795, test error 69.45
# Epoch   900, train loss 1.901941, train error 71.50,  test loss 1.746564, test error 69.53
# Training model with   4 hidden variables
# Epoch     0, train loss 2.214792, train error 83.70,  test loss 2.196842, test error 83.95
# Epoch   100, train loss 1.810632, train error 68.53,  test loss 1.687057, test error 66.22
# Epoch   200, train loss 1.796741, train error 66.57,  test loss 1.674619, test error 66.05
# Epoch   300, train loss 1.770637, train error 65.68,  test loss 1.644599, test error 64.60
# Epoch   400, train loss 1.753823, train error 64.85,  test loss 1.620035, test error 63.55
# Epoch   500, train loss 1.758715, train error 65.45,  test loss 1.630383, test error 64.88
# Epoch   600, train loss 1.754704, train error 65.28,  test loss 1.634647, test error 64.65
# Epoch   700, train loss 1.747344, train error 65.10,  test loss 1.619214, test error 63.90
# Epoch   800, train loss 1.747296, train error 64.57,  test loss 1.629960, test error 64.57
# Epoch   900, train loss 1.745372, train error 64.45,  test loss 1.636886, test error 64.03
# Training model with   6 hidden variables
# Epoch     0, train loss 2.247791, train error 83.82,  test loss 2.248332, test error 83.85
# Epoch   100, train loss 1.689286, train error 60.60,  test loss 1.536657, test error 59.83
# Epoch   200, train loss 1.631176, train error 58.05,  test loss 1.499498, test error 57.78
# Epoch   300, train loss 1.613369, train error 57.88,  test loss 1.493585, test error 57.22
# Epoch   400, train loss 1.613136, train error 57.50,  test loss 1.486694, test error 56.85
# Epoch   500, train loss 1.607860, train error 57.80,  test loss 1.475084, test error 56.38
# Epoch   600, train loss 1.604326, train error 57.78,  test loss 1.470638, test error 55.72
# Epoch   700, train loss 1.595568, train error 56.85,  test loss 1.461354, test error 55.62
# Epoch   800, train loss 1.588582, train error 56.45,  test loss 1.462375, test error 55.42
# Epoch   900, train loss 1.602155, train error 57.25,  test loss 1.487780, test error 56.25
# Training model with   8 hidden variables
# Epoch     0, train loss 2.277211, train error 86.30,  test loss 2.291154, test error 86.20
# Epoch   100, train loss 1.568080, train error 54.47,  test loss 1.398803, test error 51.35
# Epoch   200, train loss 1.464434, train error 48.40,  test loss 1.260026, test error 45.92
# Epoch   300, train loss 1.442104, train error 47.42,  test loss 1.262813, test error 46.12
# Epoch   400, train loss 1.437844, train error 48.15,  test loss 1.280740, test error 46.33
# Epoch   500, train loss 1.429527, train error 47.35,  test loss 1.272899, test error 46.38
# Epoch   600, train loss 1.422948, train error 46.67,  test loss 1.278139, test error 46.65
# Epoch   700, train loss 1.418330, train error 47.08,  test loss 1.270719, test error 45.62
# Epoch   800, train loss 1.418937, train error 47.45,  test loss 1.280542, test error 46.28
# Epoch   900, train loss 1.420051, train error 47.38,  test loss 1.288002, test error 45.97
# Training model with  10 hidden variables
# Epoch     0, train loss 2.256722, train error 84.70,  test loss 2.254447, test error 85.22
# Epoch   100, train loss 1.466518, train error 49.55,  test loss 1.280072, test error 47.90
# Epoch   200, train loss 1.408970, train error 48.35,  test loss 1.255519, test error 47.97
# Epoch   300, train loss 1.389805, train error 47.20,  test loss 1.260431, test error 47.83
# Epoch   400, train loss 1.384561, train error 46.97,  test loss 1.285474, test error 48.20
# Epoch   500, train loss 1.378913, train error 47.05,  test loss 1.289684, test error 49.17
# Epoch   600, train loss 1.374301, train error 46.33,  test loss 1.309247, test error 48.72
# Epoch   700, train loss 1.364556, train error 46.03,  test loss 1.302684, test error 48.72
# Epoch   800, train loss 1.365715, train error 45.95,  test loss 1.307492, test error 48.90
# Epoch   900, train loss 1.358765, train error 46.25,  test loss 1.323525, test error 48.88
# Training model with  14 hidden variables
# Epoch     0, train loss 2.171965, train error 80.40,  test loss 2.129037, test error 78.43
# Epoch   100, train loss 1.453344, train error 50.38,  test loss 1.352569, test error 50.97
# Epoch   200, train loss 1.393333, train error 47.62,  test loss 1.362601, test error 51.40
# Epoch   300, train loss 1.354517, train error 46.67,  test loss 1.350791, test error 50.25
# Epoch   400, train loss 1.338536, train error 45.67,  test loss 1.352097, test error 49.67
# Epoch   500, train loss 1.330100, train error 45.62,  test loss 1.355396, test error 49.17
# Epoch   600, train loss 1.324391, train error 45.38,  test loss 1.382401, test error 49.53
# Epoch   700, train loss 1.314404, train error 45.00,  test loss 1.381387, test error 48.45
# Epoch   800, train loss 1.306741, train error 44.80,  test loss 1.388830, test error 49.15
# Epoch   900, train loss 1.305202, train error 44.75,  test loss 1.408767, test error 50.10
# Training model with  18 hidden variables
# Epoch     0, train loss 2.168777, train error 81.90,  test loss 2.125149, test error 80.50
# Epoch   100, train loss 1.345274, train error 45.75,  test loss 1.314043, test error 48.15
# Epoch   200, train loss 1.249338, train error 42.70,  test loss 1.340636, test error 49.80
# Epoch   300, train loss 1.201334, train error 40.40,  test loss 1.385041, test error 49.85
# Epoch   400, train loss 1.190788, train error 40.95,  test loss 1.429120, test error 49.62
# Epoch   500, train loss 1.157073, train error 39.40,  test loss 1.452132, test error 51.42
# Epoch   600, train loss 1.149902, train error 39.85,  test loss 1.485173, test error 52.08
# Epoch   700, train loss 1.152253, train error 39.58,  test loss 1.522988, test error 52.03
# Epoch   800, train loss 1.134180, train error 39.05,  test loss 1.537652, test error 52.25
# Epoch   900, train loss 1.122988, train error 38.35,  test loss 1.533294, test error 51.70
# Training model with  22 hidden variables
# Epoch     0, train loss 2.145162, train error 79.35,  test loss 2.111772, test error 78.68
# Epoch   100, train loss 1.264782, train error 42.53,  test loss 1.311347, test error 48.20
# Epoch   200, train loss 1.157400, train error 38.95,  test loss 1.382716, test error 49.45
# Epoch   300, train loss 1.098392, train error 36.17,  test loss 1.440561, test error 49.35
# Epoch   400, train loss 1.067833, train error 36.17,  test loss 1.542954, test error 51.60
# Epoch   500, train loss 1.035885, train error 34.62,  test loss 1.575044, test error 51.42
# Epoch   600, train loss 1.013833, train error 35.15,  test loss 1.623072, test error 51.80
# Epoch   700, train loss 1.009647, train error 34.80,  test loss 1.677013, test error 52.53
# Epoch   800, train loss 0.990380, train error 33.78,  test loss 1.739979, test error 53.08
# Epoch   900, train loss 0.976847, train error 33.90,  test loss 1.786315, test error 53.17
# Training model with  26 hidden variables
# Epoch     0, train loss 2.167637, train error 79.62,  test loss 2.139779, test error 79.32
# Epoch   100, train loss 1.196680, train error 38.80,  test loss 1.308612, test error 48.33
# Epoch   200, train loss 1.061931, train error 35.05,  test loss 1.436052, test error 50.15
# Epoch   300, train loss 0.977579, train error 33.05,  test loss 1.548918, test error 52.10
# Epoch   400, train loss 0.939188, train error 32.22,  test loss 1.653196, test error 53.58
# Epoch   500, train loss 0.897849, train error 30.47,  test loss 1.748672, test error 53.92
# Epoch   600, train loss 0.868084, train error 29.45,  test loss 1.830080, test error 54.85
# Epoch   700, train loss 0.857320, train error 29.50,  test loss 1.905945, test error 54.83
# Epoch   800, train loss 0.849025, train error 29.32,  test loss 2.004601, test error 55.30
# Epoch   900, train loss 0.834275, train error 28.22,  test loss 2.046231, test error 55.17
# Training model with  30 hidden variables
# Epoch     0, train loss 2.120333, train error 78.18,  test loss 2.091837, test error 79.07
# Epoch   100, train loss 1.101713, train error 36.70,  test loss 1.372050, test error 49.12
# Epoch   200, train loss 0.922039, train error 31.50,  test loss 1.601332, test error 51.83
# Epoch   300, train loss 0.849098, train error 28.97,  test loss 1.779141, test error 52.92
# Epoch   400, train loss 0.797021, train error 27.30,  test loss 1.947929, test error 54.17
# Epoch   500, train loss 0.761046, train error 25.78,  test loss 2.085658, test error 54.72
# Epoch   600, train loss 0.726624, train error 24.22,  test loss 2.180915, test error 54.90
# Epoch   700, train loss 0.709523, train error 23.80,  test loss 2.338821, test error 54.60
# Epoch   800, train loss 0.691710, train error 23.05,  test loss 2.460964, test error 56.38
# Epoch   900, train loss 0.683931, train error 23.43,  test loss 2.581728, test error 56.80
# Training model with  35 hidden variables
# Epoch     0, train loss 2.103104, train error 80.05,  test loss 2.060571, test error 79.90
# Epoch   100, train loss 1.032520, train error 34.57,  test loss 1.436903, test error 50.70
# Epoch   200, train loss 0.793592, train error 26.95,  test loss 1.708990, test error 52.65
# Epoch   300, train loss 0.659403, train error 22.15,  test loss 2.031361, test error 53.83
# Epoch   400, train loss 0.590953, train error 20.38,  test loss 2.392496, test error 54.80
# Epoch   500, train loss 0.550056, train error 19.10,  test loss 2.750244, test error 55.62
# Epoch   600, train loss 0.504675, train error 17.95,  test loss 3.120342, test error 55.55
# Epoch   700, train loss 0.456402, train error 16.03,  test loss 3.430631, test error 56.22
# Epoch   800, train loss 0.496016, train error 17.43,  test loss 3.814991, test error 56.72
# Epoch   900, train loss 0.448734, train error 15.90,  test loss 3.991464, test error 56.05
# Training model with  40 hidden variables
# Epoch     0, train loss 2.109167, train error 78.40,  test loss 2.055648, test error 77.95
# Epoch   100, train loss 0.917695, train error 29.60,  test loss 1.398395, test error 48.45
# Epoch   200, train loss 0.631541, train error 19.30,  test loss 1.840111, test error 52.38
# Epoch   300, train loss 0.490994, train error 15.32,  test loss 2.409579, test error 54.72
# Epoch   400, train loss 0.418127, train error 13.07,  test loss 2.972811, test error 54.62
# Epoch   500, train loss 0.372683, train error 12.32,  test loss 3.744191, test error 55.60
# Epoch   600, train loss 0.389726, train error 13.32,  test loss 4.386261, test error 55.42
# Epoch   700, train loss 0.254645, train error 8.38,  test loss 5.004167, test error 57.40
# Epoch   800, train loss 0.252230, train error 8.78,  test loss 5.663304, test error 57.08
# Epoch   900, train loss 0.306871, train error 10.43,  test loss 6.161999, test error 57.05
# Training model with  45 hidden variables
# Epoch     0, train loss 2.099864, train error 77.97,  test loss 2.054305, test error 76.03
# Epoch   100, train loss 0.795387, train error 25.70,  test loss 1.585846, test error 51.85
# Epoch   200, train loss 0.472032, train error 14.62,  test loss 2.325224, test error 53.38
# Epoch   300, train loss 0.332808, train error 11.12,  test loss 3.365959, test error 55.05
# Epoch   400, train loss 0.221102, train error 7.72,  test loss 4.541284, test error 55.40
# Epoch   500, train loss 0.221164, train error 8.55,  test loss 5.886872, test error 56.60
# Epoch   600, train loss 0.122550, train error 4.22,  test loss 7.007998, test error 56.62
# Epoch   700, train loss 0.011996, train error 0.00,  test loss 8.002273, test error 56.42
# Epoch   800, train loss 0.006825, train error 0.00,  test loss 8.694917, test error 56.33
# Epoch   900, train loss 0.005033, train error 0.00,  test loss 9.167710, test error 56.30
# Training model with  50 hidden variables
# Epoch     0, train loss 2.057089, train error 76.53,  test loss 2.003564, test error 77.00
# Epoch   100, train loss 0.703930, train error 21.90,  test loss 1.599772, test error 50.62
# Epoch   200, train loss 0.339039, train error 10.43,  test loss 2.672687, test error 53.12
# Epoch   300, train loss 0.145226, train error 3.57,  test loss 4.189425, test error 55.05
# Epoch   400, train loss 0.025916, train error 0.00,  test loss 5.624856, test error 54.42
# Epoch   500, train loss 0.011931, train error 0.00,  test loss 6.554538, test error 55.03
# Epoch   600, train loss 0.007665, train error 0.00,  test loss 7.121610, test error 55.12
# Epoch   700, train loss 0.005472, train error 0.00,  test loss 7.558983, test error 55.10
# Epoch   800, train loss 0.004221, train error 0.00,  test loss 7.912598, test error 55.25
# Epoch   900, train loss 0.003406, train error 0.00,  test loss 8.203635, test error 55.03
# Training model with  55 hidden variables
# Epoch     0, train loss 2.081692, train error 77.25,  test loss 2.046298, test error 77.53
# Epoch   100, train loss 0.636445, train error 19.72,  test loss 1.651048, test error 51.38
# Epoch   200, train loss 0.224710, train error 5.07,  test loss 2.913015, test error 53.60
# Epoch   300, train loss 0.045857, train error 0.15,  test loss 4.586213, test error 54.65
# Epoch   400, train loss 0.015399, train error 0.00,  test loss 5.631473, test error 54.70
# Epoch   500, train loss 0.008945, train error 0.00,  test loss 6.277850, test error 55.15
# Epoch   600, train loss 0.006074, train error 0.00,  test loss 6.720326, test error 54.95
# Epoch   700, train loss 0.004524, train error 0.00,  test loss 7.066634, test error 55.00
# Epoch   800, train loss 0.003572, train error 0.00,  test loss 7.348633, test error 55.03
# Epoch   900, train loss 0.002909, train error 0.00,  test loss 7.596437, test error 55.22
# Training model with  60 hidden variables
# Epoch     0, train loss 2.039215, train error 75.60,  test loss 1.978111, test error 75.57
# Epoch   100, train loss 0.521900, train error 15.50,  test loss 1.845575, test error 53.30
# Epoch   200, train loss 0.087046, train error 0.35,  test loss 3.669840, test error 55.75
# Epoch   300, train loss 0.017790, train error 0.00,  test loss 4.979022, test error 56.35
# Epoch   400, train loss 0.008856, train error 0.00,  test loss 5.644876, test error 56.35
# Epoch   500, train loss 0.005691, train error 0.00,  test loss 6.099998, test error 56.30
# Epoch   600, train loss 0.004086, train error 0.00,  test loss 6.438107, test error 56.17
# Epoch   700, train loss 0.003172, train error 0.00,  test loss 6.708926, test error 56.25
# Epoch   800, train loss 0.002544, train error 0.00,  test loss 6.932749, test error 56.28
# Epoch   900, train loss 0.002119, train error 0.00,  test loss 7.123355, test error 56.22
# Training model with  70 hidden variables
# Epoch     0, train loss 2.073206, train error 77.93,  test loss 2.027141, test error 77.90
# Epoch   100, train loss 0.356360, train error 8.30,  test loss 1.912682, test error 52.35
# Epoch   200, train loss 0.033523, train error 0.00,  test loss 3.619866, test error 53.97
# Epoch   300, train loss 0.010876, train error 0.00,  test loss 4.405865, test error 54.05
# Epoch   400, train loss 0.006130, train error 0.00,  test loss 4.849506, test error 54.25
# Epoch   500, train loss 0.004140, train error 0.00,  test loss 5.161870, test error 54.40
# Epoch   600, train loss 0.003073, train error 0.00,  test loss 5.396518, test error 54.40
# Epoch   700, train loss 0.002410, train error 0.00,  test loss 5.586977, test error 54.33
# Epoch   800, train loss 0.001971, train error 0.00,  test loss 5.746756, test error 54.35
# Epoch   900, train loss 0.001657, train error 0.00,  test loss 5.884825, test error 54.45
# Training model with  80 hidden variables
# Epoch     0, train loss 2.010383, train error 74.95,  test loss 1.944138, test error 73.95
# Epoch   100, train loss 0.232981, train error 4.30,  test loss 2.056881, test error 50.28
# Epoch   200, train loss 0.019457, train error 0.00,  test loss 3.371933, test error 51.17
# Epoch   300, train loss 0.007948, train error 0.00,  test loss 3.926011, test error 51.17
# Epoch   400, train loss 0.004730, train error 0.00,  test loss 4.254572, test error 51.40
# Epoch   500, train loss 0.003269, train error 0.00,  test loss 4.490947, test error 51.58
# Epoch   600, train loss 0.002464, train error 0.00,  test loss 4.670842, test error 51.58
# Epoch   700, train loss 0.001959, train error 0.00,  test loss 4.819479, test error 51.70
# Epoch   800, train loss 0.001616, train error 0.00,  test loss 4.942347, test error 51.80
# Epoch   900, train loss 0.001367, train error 0.00,  test loss 5.051071, test error 51.85
# Training model with  90 hidden variables
# Epoch     0, train loss 1.985160, train error 73.55,  test loss 1.921041, test error 72.30
# Epoch   100, train loss 0.131173, train error 0.90,  test loss 2.131678, test error 50.42
# Epoch   200, train loss 0.014158, train error 0.00,  test loss 3.108085, test error 50.47
# Epoch   300, train loss 0.006276, train error 0.00,  test loss 3.511078, test error 50.85
# Epoch   400, train loss 0.003854, train error 0.00,  test loss 3.762291, test error 50.80
# Epoch   500, train loss 0.002714, train error 0.00,  test loss 3.942583, test error 50.97
# Epoch   600, train loss 0.002068, train error 0.00,  test loss 4.083916, test error 51.05
# Epoch   700, train loss 0.001655, train error 0.00,  test loss 4.199534, test error 51.20
# Epoch   800, train loss 0.001371, train error 0.00,  test loss 4.299736, test error 51.22
# Epoch   900, train loss 0.001165, train error 0.00,  test loss 4.384402, test error 51.35
# Training model with 100 hidden variables
# Epoch     0, train loss 2.004124, train error 74.47,  test loss 1.951389, test error 75.35
# Epoch   100, train loss 0.103053, train error 0.47,  test loss 2.262891, test error 51.78
# Epoch   200, train loss 0.012783, train error 0.00,  test loss 3.139587, test error 51.95
# Epoch   300, train loss 0.005899, train error 0.00,  test loss 3.512379, test error 51.95
# Epoch   400, train loss 0.003653, train error 0.00,  test loss 3.748274, test error 52.17
# Epoch   500, train loss 0.002592, train error 0.00,  test loss 3.919123, test error 52.08
# Epoch   600, train loss 0.001984, train error 0.00,  test loss 4.052294, test error 52.03
# Epoch   700, train loss 0.001593, train error 0.00,  test loss 4.162434, test error 51.92
# Epoch   800, train loss 0.001323, train error 0.00,  test loss 4.256021, test error 51.95
# Epoch   900, train loss 0.001125, train error 0.00,  test loss 4.337743, test error 51.95
# Training model with 120 hidden variables
# Epoch     0, train loss 1.964612, train error 73.38,  test loss 1.878433, test error 73.32
# Epoch   100, train loss 0.048485, train error 0.00,  test loss 2.198020, test error 49.60
# Epoch   200, train loss 0.009359, train error 0.00,  test loss 2.823980, test error 49.83
# Epoch   300, train loss 0.004670, train error 0.00,  test loss 3.103222, test error 50.03
# Epoch   400, train loss 0.002993, train error 0.00,  test loss 3.285744, test error 49.97
# Epoch   500, train loss 0.002159, train error 0.00,  test loss 3.419246, test error 50.05
# Epoch   600, train loss 0.001669, train error 0.00,  test loss 3.525003, test error 50.00
# Epoch   700, train loss 0.001351, train error 0.00,  test loss 3.612640, test error 49.97
# Epoch   800, train loss 0.001128, train error 0.00,  test loss 3.687081, test error 49.95
# Epoch   900, train loss 0.000965, train error 0.00,  test loss 3.751997, test error 49.97
# Training model with 140 hidden variables
# Epoch     0, train loss 1.959875, train error 72.32,  test loss 1.887887, test error 72.57
# Epoch   100, train loss 0.036159, train error 0.00,  test loss 2.247090, test error 49.97
# Epoch   200, train loss 0.008071, train error 0.00,  test loss 2.736542, test error 49.38
# Epoch   300, train loss 0.004139, train error 0.00,  test loss 2.974656, test error 49.25
# Epoch   400, train loss 0.002687, train error 0.00,  test loss 3.129450, test error 49.03
# Epoch   500, train loss 0.001956, train error 0.00,  test loss 3.244358, test error 49.00
# Epoch   600, train loss 0.001520, train error 0.00,  test loss 3.335882, test error 49.03
# Epoch   700, train loss 0.001235, train error 0.00,  test loss 3.412510, test error 49.10
# Epoch   800, train loss 0.001034, train error 0.00,  test loss 3.477234, test error 49.10
# Epoch   900, train loss 0.000887, train error 0.00,  test loss 3.534078, test error 49.20
# Training model with 160 hidden variables
# Epoch     0, train loss 1.932251, train error 70.97,  test loss 1.841279, test error 70.93
# Epoch   100, train loss 0.029414, train error 0.00,  test loss 1.994909, test error 47.92
# Epoch   200, train loss 0.007325, train error 0.00,  test loss 2.380150, test error 48.28
# Epoch   300, train loss 0.003849, train error 0.00,  test loss 2.569030, test error 48.15
# Epoch   400, train loss 0.002522, train error 0.00,  test loss 2.694206, test error 48.28
# Epoch   500, train loss 0.001845, train error 0.00,  test loss 2.788381, test error 48.22
# Epoch   600, train loss 0.001440, train error 0.00,  test loss 2.863055, test error 48.28
# Epoch   700, train loss 0.001172, train error 0.00,  test loss 2.925164, test error 48.35
# Epoch   800, train loss 0.000983, train error 0.00,  test loss 2.979117, test error 48.33
# Epoch   900, train loss 0.000843, train error 0.00,  test loss 3.025622, test error 48.25
# Training model with 180 hidden variables
# Epoch     0, train loss 1.918511, train error 71.20,  test loss 1.861705, test error 73.50
# Epoch   100, train loss 0.024989, train error 0.00,  test loss 2.083634, test error 49.10
# Epoch   200, train loss 0.006646, train error 0.00,  test loss 2.425940, test error 48.70
# Epoch   300, train loss 0.003550, train error 0.00,  test loss 2.601044, test error 48.67
# Epoch   400, train loss 0.002349, train error 0.00,  test loss 2.717004, test error 48.55
# Epoch   500, train loss 0.001727, train error 0.00,  test loss 2.802573, test error 48.50
# Epoch   600, train loss 0.001352, train error 0.00,  test loss 2.872794, test error 48.55
# Epoch   700, train loss 0.001104, train error 0.00,  test loss 2.930858, test error 48.55
# Epoch   800, train loss 0.000928, train error 0.00,  test loss 2.980561, test error 48.58
# Epoch   900, train loss 0.000797, train error 0.00,  test loss 3.024227, test error 48.47
# Training model with 200 hidden variables
# Epoch     0, train loss 1.916378, train error 70.20,  test loss 1.834676, test error 69.85
# Epoch   100, train loss 0.021059, train error 0.00,  test loss 1.992005, test error 47.25
# Epoch   200, train loss 0.006057, train error 0.00,  test loss 2.305793, test error 47.08
# Epoch   300, train loss 0.003299, train error 0.00,  test loss 2.466022, test error 47.10
# Epoch   400, train loss 0.002203, train error 0.00,  test loss 2.575348, test error 46.88
# Epoch   500, train loss 0.001628, train error 0.00,  test loss 2.656755, test error 47.00
# Epoch   600, train loss 0.001279, train error 0.00,  test loss 2.722608, test error 47.15
# Epoch   700, train loss 0.001046, train error 0.00,  test loss 2.776744, test error 47.05
# Epoch   800, train loss 0.000881, train error 0.00,  test loss 2.823967, test error 47.05
# Epoch   900, train loss 0.000758, train error 0.00,  test loss 2.865199, test error 47.12
# Training model with 250 hidden variables
# Epoch     0, train loss 1.922887, train error 70.43,  test loss 1.827408, test error 70.20
# Epoch   100, train loss 0.017037, train error 0.00,  test loss 1.881698, test error 46.97
# Epoch   200, train loss 0.005271, train error 0.00,  test loss 2.119724, test error 46.85
# Epoch   300, train loss 0.002938, train error 0.00,  test loss 2.245941, test error 46.83
# Epoch   400, train loss 0.001984, train error 0.00,  test loss 2.333927, test error 46.72
# Epoch   500, train loss 0.001478, train error 0.00,  test loss 2.400817, test error 46.67
# Epoch   600, train loss 0.001167, train error 0.00,  test loss 2.454540, test error 46.58
# Epoch   700, train loss 0.000958, train error 0.00,  test loss 2.499451, test error 46.60
# Epoch   800, train loss 0.000809, train error 0.00,  test loss 2.537859, test error 46.50
# Epoch   900, train loss 0.000698, train error 0.00,  test loss 2.571542, test error 46.50
# Training model with 300 hidden variables
# Epoch     0, train loss 1.875199, train error 67.82,  test loss 1.812855, test error 69.05
# Epoch   100, train loss 0.014589, train error 0.00,  test loss 1.849981, test error 46.35
# Epoch   200, train loss 0.004836, train error 0.00,  test loss 2.061947, test error 46.10
# Epoch   300, train loss 0.002737, train error 0.00,  test loss 2.178478, test error 45.92
# Epoch   400, train loss 0.001863, train error 0.00,  test loss 2.258818, test error 45.90
# Epoch   500, train loss 0.001394, train error 0.00,  test loss 2.319948, test error 45.92
# Epoch   600, train loss 0.001104, train error 0.00,  test loss 2.369010, test error 45.90
# Epoch   700, train loss 0.000909, train error 0.00,  test loss 2.410632, test error 45.88
# Epoch   800, train loss 0.000769, train error 0.00,  test loss 2.446182, test error 45.88
# Epoch   900, train loss 0.000665, train error 0.00,  test loss 2.477323, test error 45.90
# Training model with 400 hidden variables
# Epoch     0, train loss 1.841499, train error 66.12,  test loss 1.776573, test error 69.35
# Epoch   100, train loss 0.011722, train error 0.00,  test loss 1.694650, test error 44.30
# Epoch   200, train loss 0.004194, train error 0.00,  test loss 1.858146, test error 44.33
# Epoch   300, train loss 0.002427, train error 0.00,  test loss 1.952183, test error 44.10
# Epoch   400, train loss 0.001672, train error 0.00,  test loss 2.016436, test error 44.03
# Epoch   500, train loss 0.001260, train error 0.00,  test loss 2.066885, test error 44.15
# Epoch   600, train loss 0.001003, train error 0.00,  test loss 2.107347, test error 44.08
# Epoch   700, train loss 0.000829, train error 0.00,  test loss 2.141382, test error 44.05
# Epoch   800, train loss 0.000704, train error 0.00,  test loss 2.170634, test error 43.95
# Epoch   900, train loss 0.000609, train error 0.00,  test loss 2.196605, test error 43.90

# %%
# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
